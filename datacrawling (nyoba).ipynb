# %%
# !pip install --upgrade git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to c:\users\asus\appdata\local\temp\pip-req-build-g7x_btug
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit 786815dd05681e2421cd03aa9acf5ab5c773bce9
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Created wheel for snscrape: filename=snscrape-0.6.2.20230321.dev13+g786815d-py3-none-any.whl size=73847 sha256=a982f4b9ff05f32a327afb7b4ca13b037ea5a0aabbb37bc4fca9c4a44425dc5b
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# !pip show snscrape
# Out:
# Name: snscrape
# Version: 0.6.2.20230321.dev13+g786815d
# Summary: A social networking service scraper
# Home-page:
# Author: JustAnotherArchivist
# Author-email:
# License:
# Location: c:\users\asus\appdata\roaming\python\python39\site-packages
# Requires: lxml, requests, filelock, beautifulsoup4
# Required-by:

# %%
kamjar = []

for i, tweet in enumerate(sntwitter.TwitterSearchScraper('kampus mengajar since:2021-06-01 until:2023-02-28').get_items()):
    if i>15000:
        break
    kamjar.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12240\3456691387.py:6: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   kamjar.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
# Skipping unrecognised entry ID: 'promoted-tweet-1661733639166775296-315be8f370622ad8'
# Skipping unrecognised entry ID: 'promoted-tweet-1658503663453716482-315be03b34ec7611'
# Skipping unrecognised entry ID: 'promoted-tweet-1661733639166775296-315b00d8423f8c24'
# Skipping unrecognised entry ID: 'promoted-tweet-1658503663453716482-315b7acb8f37e4bd'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-315b728da777a0aa'
# Skipping unrecognised entry ID: 'promoted-tweet-1661733639166775296-315b805075cc4080'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-315b9b07e84c56c1'
# Skipping unrecognised entry ID: 'promoted-tweet-1658503663453716482-315bca91ddc9b6f1'
# ...

# %%
kamjar = []

for i, tweet in enumerate(sntwitter.TwitterSearchScraper('kampus mengajar since:2021-06-01 until:2023-02-28').get_items()):
    if i>15000:
        break
    tweet_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username])

# %%
lpdp_list = []

# %%
tweets = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper(query = "#opportunity").get_items()):
    if i>100:
        break
    tweets.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.retweetCount, tweet.replyCount, tweet.lang,
                   tweet.sourceLabel, tweet.content])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16488\963793248.py:7: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweet.sourceLabel, tweet.content])
# Skipping unrecognised entry ID: 'promoted-tweet-1658503663453716482-2e4be556e19f7f72'

# %%
lpdp = pd.DataFrame(lpdp_list, columns = ['Datetime', 'TweetID', 'Text', 'Username'])

# %%
lpdp
# Out:
#                       Datetime              TweetID  \
# 0    2023-02-05 23:58:58+00:00  1622384315882676224
# 1    2023-02-05 23:54:44+00:00  1622383254002368514
# 2    2023-02-05 23:53:19+00:00  1622382896064466945
# 3    2023-02-05 23:52:00+00:00  1622382563460550656
# 4    2023-02-05 23:51:58+00:00  1622382555021586432
# ...                        ...                  ...
# 7673 2023-01-01 02:15:40+00:00  1609372754415087616
# 7674 2023-01-01 02:06:48+00:00  1609370526656659457
# 7675 2023-01-01 01:57:04+00:00  1609368073852813315
# 7676 2023-01-01 01:50:04+00:00  1609366313092415488
# 7677 2023-01-01 01:10:34+00:00  1609356372663218177
#
#                                                    Text       Username
# 0               Ga cuma bansos aja yg nyasar, lpdp juga       rnrfkhri
# 1     Ya Allah, ga kebayang seperti apa dingin nya, ...   VellocityBEE
# 2     @safiraaan_ Tadi bilangnya kebanyakan awardeen...       zulfayed
# ...

# %%
lpdp.to_csv("F:\Documents ASUS\MATH\#8\S.MAT 2023\Coba\lpdp2023.csv")

# %%
tweet_list = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper('magang merdeka since:2022-01-01 until:2022-12-31').get_items()):
    if i>15000:
        break
    tweet_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_4432\980854508.py:4: FutureWarning: content is deprecated, use rawContent instead
#   tweet_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username])

# %%
tweet = pd.DataFrame(tweet_list, columns=['Datetime', 'TweetID', 'Text', 'Username'])

# %%
tweet
# Out:
#                       Datetime              TweetID  \
# 0    2022-12-30 23:34:16+00:00  1608969750780203009
# 1    2022-12-30 23:03:06+00:00  1608961908421591041
# 2    2022-12-30 20:51:23+00:00  1608928758765060097
# 3    2022-12-30 19:43:31+00:00  1608911681593438209
# 4    2022-12-30 17:47:29+00:00  1608882478974119936
# ...                        ...                  ...
# 8690 2022-01-01 03:23:45+00:00  1477118317768810502
# 8691 2022-01-01 03:13:23+00:00  1477115710258122754
# 8692 2022-01-01 01:05:35+00:00  1477083547299041284
# 8693 2022-01-01 00:50:27+00:00  1477079739181383681
# 8694 2022-01-01 00:42:28+00:00  1477077729526706179
#
#                                                    Text        Username
# 0     @kaidocye3 @unilabase Mbkm (merdeka belajar ka...     lovedbymeng
# 1     Susahnya anak ekstensi kayanya gak bakalan bis...     vantasticme
# 2     @collegemenfess kampus merdeka? itumah banyak ...  letsguesswhome
# ...

# %%
tweet.to_csv("F:\Documents ASUS\MATH\#8\S.MAT 2023\Coba\magang_merdeka1.csv")

# %%
msib_list = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper('msib since:2022-01-01 until:2022-12-31').get_items()):
    if i>15000:
        break
    msib_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_5520\3448128966.py:4: FutureWarning: content is deprecated, use rawContent instead
#   msib_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username])

# %%
msib = pd.DataFrame(msib_list, columns=['Datetime', 'TweetID', 'Text', 'Username'])

# %%
msib
# Out:
#                       Datetime              TweetID  \
# 0    2022-12-30 23:05:57+00:00  1608962625358147585
# 1    2022-12-30 22:00:58+00:00  1608946271389356032
# 2    2022-12-30 19:39:40+00:00  1608910710582697984
# 3    2022-12-30 17:17:54+00:00  1608875035799990272
# 4    2022-12-30 16:39:34+00:00  1608865387462168577
# ...                        ...                  ...
# 6085 2022-01-01 08:42:41+00:00  1477198582226640896
# 6086 2022-01-01 07:42:14+00:00  1477183369251213312
# 6087 2022-01-01 06:27:03+00:00  1477164447164604419
# 6088 2022-01-01 04:42:38+00:00  1477138171385114628
# 6089 2022-01-01 03:43:31+00:00  1477123295476654080
#
#                                                    Text         Username
# 0     itungannya masih semt 3 tp nekat ikut msib. wm...      t____5____t
# 1                           @telurenak_ anjay nak msib.        haagwntus
# 2     Merah Putih) dan sebagai mitra terfavorit kate...  BJKT1Terpercaya
# ...

# %%
msib.to_csv("F:\Documents ASUS\MATH\#8\S.MAT 2023\Coba\msib.csv")

# %%
studi_independen_list = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper('studi independen since:2022-01-01 until:2022-12-31').get_items()):
    if i>15000:
        break
    studi_independen_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6700\555775227.py:4: FutureWarning: content is deprecated, use rawContent instead
#   studi_independen_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username])

# %%
studi_independen = pd.DataFrame(studi_independen_list, columns=['Datetime', 'TweetID', 'Text', 'Username'])

# %%
studi_independen
# Out:
#                       Datetime              TweetID  \
# 0    2022-12-30 20:51:23+00:00  1608928758765060097
# 1    2022-12-30 19:39:40+00:00  1608910710582697984
# 2    2022-12-30 16:11:40+00:00  1608858365324849155
# 3    2022-12-30 15:55:39+00:00  1608854334267330563
# 4    2022-12-30 11:41:48+00:00  1608790451506774016
# ...                        ...                  ...
# 4726 2022-01-01 15:29:10+00:00  1477300875034984449
# 4727 2022-01-01 12:06:34+00:00  1477249888777740289
# 4728 2022-01-01 08:15:08+00:00  1477191648928931840
# 4729 2022-01-01 01:21:13+00:00  1477087484538281984
# 4730 2022-01-01 01:02:00+00:00  1477082646870065152
#
#                                                    Text         Username
# 0     @collegemenfess kampus merdeka? itumah banyak ...   letsguesswhome
# 1     Merah Putih) dan sebagai mitra terfavorit kate...  BJKT1Terpercaya
# 2     @vancitymarky @undipmenfess MSIB tu program Ka...        daily__d_
# ...

# %%
studi_independen.to_csv("F:\Documents ASUS\MATH\#8\S.MAT 2023\Coba\studi_independen.csv")

# %%
stupen_list = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper('stupen since:2022-01-01 until:2022-12-31').get_items()):
    if i>15000:
        break
    stupen_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6036\2086895930.py:4: FutureWarning: content is deprecated, use rawContent instead
#   stupen_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username])

# %%
stupen = pd.DataFrame(stupen_list, columns=['Datetime', 'TweetID', 'Text', 'Username'])

# %%
stupen
# Out:
#                       Datetime              TweetID  \
# 0    2022-12-30 23:20:47+00:00  1608966355751174144
# 1    2022-12-30 23:17:30+00:00  1608965531679461376
# 2    2022-12-30 23:13:05+00:00  1608964418087587840
# 3    2022-12-30 20:58:34+00:00  1608930566623350784
# 4    2022-12-30 20:19:58+00:00  1608920855098314752
# ...                        ...                  ...
# 8420 2022-01-01 11:51:46+00:00  1477246167176024065
# 8421 2022-01-01 10:37:45+00:00  1477227540947292161
# 8422 2022-01-01 08:06:28+00:00  1477189468868288514
# 8423 2022-01-01 05:52:11+00:00  1477155673284644866
# 8424 2022-01-01 00:25:02+00:00  1477073342373011460
#
#                                                    Text         Username
# 0     @JiriSimon Jako sorry,ale člověku stačí první ...         ettel831
# 1     udh lewat dan bnrn ganti 🤣, soalnya apa yg w r...         C_andyRj
# 2     D, Q, Y, W, W, R sih...mereka semua orang2 bar...  mingyukookie_97
# ...

# %%
stupen.to_csv("F:\Documents ASUS\MATH\#8\S.MAT 2023\Coba\stupen.csv")

# %%
! pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to c:\users\asus\appdata\local\temp\pip-req-build-c5wjgn87
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit e47fbe3d1f078582d24d4b7b04f0ab4e41ddff1c
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Created wheel for snscrape: filename=snscrape-0.6.1.20230314-py3-none-any.whl size=72060 sha256=d8dcdf25f86215ae8c947621645121bde9ac99f0e001a50803430a95d179432e
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
sib_list = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper('#msib since:2022-01-01 until:2022-12-31').get_items()):
    if i>15000:
        break
    sib_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7376\1401558025.py:4: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   sib_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username])

# %%
sib = pd.DataFrame(sib_list, columns=['Datetime', 'TweetID', 'Text', 'Username'])

# %%
sib
# Out:
#                      Datetime              TweetID  \
# 0   2022-12-30 10:17:47+00:00  1608769311002484736
# 1   2022-12-30 04:09:29+00:00  1608676625734053888
# 2   2022-12-30 02:25:57+00:00  1608650567403937793
# 3   2022-12-27 09:47:06+00:00  1607674426086281218
# 4   2022-12-26 12:48:14+00:00  1607357617982312448
# ..                        ...                  ...
# 140 2022-01-10 07:04:19+00:00  1480435318306131970
# 141 2022-01-09 22:06:53+00:00  1480300067789672456
# 142 2022-01-09 09:34:36+00:00  1480110749955416070
# 143 2022-01-04 06:25:23+00:00  1478251193302355968
# 144 2022-01-03 07:04:13+00:00  1477898575619133445
#
#                                                   Text         Username
# 0    Pengen ga sih skripsi sambil digaji? Pantengin...    widyarobotics
# 1    Halo#SivitasUPI \nMSIB angkatan 4 telah dibuka...     upi_official
# 2    #kenalan dong sama #Program #kampusmerdeka . S...      CocoEdukasi
# ...

# %%
sib.to_csv("F:\Documents ASUS\MATH\#8\S.MAT 2023\Coba\sib.csv")

# %%
msib2023 = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper('msib since:2023-01-01 until:2023-01-31').get_items()):
    if i>15000:
        break
    msib2023.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6404\1090520039.py:4: FutureWarning: content is deprecated, use rawContent instead
#   msib2023.append([tweet.date, tweet.id, tweet.content, tweet.user.username])

# %%
msib2023_df = pd.DataFrame(msib2023, columns=['Datetime', 'TweetID', 'Text', 'Username'])

# %% [markdown]
# msib2023_df

# %%
msib2023_df
# Out:
#                       Datetime              TweetID  \
# 0    2023-01-30 23:42:20+00:00  1620205804937949184
# 1    2023-01-30 23:41:55+00:00  1620205700839518208
# 2    2023-01-30 23:04:48+00:00  1620196360783015936
# 3    2023-01-30 23:03:49+00:00  1620196112392159234
# 4    2023-01-30 22:54:12+00:00  1620193691565690880
# ...                        ...                  ...
# 3833 2023-01-01 04:08:56+00:00  1609401261270630407
# 3834 2023-01-01 02:59:29+00:00  1609383781596811264
# 3835 2023-01-01 02:32:07+00:00  1609376895568875520
# 3836 2023-01-01 02:31:45+00:00  1609376802795032577
# 3837 2023-01-01 01:37:35+00:00  1609363173676834826
#
#                                                    Text         Username
# 0                                   @xxxxxxxhah belommm       pixxieyoun
# 1     [cm] ada ga sih yg lolos msib tanpa lampirin p...   collegemenfess
# 2     Ada yg udh dapat email pengunduran jadwal surv...       xxxxxxxhah
# ...

# %%
msib2023_df.to_csv("F:\Documents ASUS\MATH\#8\S.MAT 2023\Coba\msib2023.csv")

# %%
kampus_mengajar = []

for i, tweet in enumerate(sntwitter.TwitterSearchScraper('kampus mengajar since:2021-06-01 until:2023-02-28').get_items()):
    if i>15000:
        break
    kampus_mengajar.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
# Out:
# Error retrieving https://api.twitter.com/2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&include_ext_has_nft_avatar=1&include_ext_is_blue_verified=1&include_ext_verified_type=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_ext_alt_text=true&include_ext_limited_action_results=false&include_quote_count=true&include_reply_count=1&tweet_mode=extended&include_ext_collab_control=true&include_ext_views=true&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&include_ext_sensitive_media_warning=true&include_ext_trusted_friends_metadata=true&send_error_codes=true&simple_quoted_tweet=true&q=kampus+mengajar+since%3A2021-06-01+until%3A2023-02-28&tweet_search_mode=live&count=20&query_source=spelling_expansion_revert_click&pc=1&spelling_corrections=1&include_ext_edit_
# ...

# %%
kampus_mengajar_df = pd.DataFrame(msib2023, columns=['Datetime', 'TweetID', 'Text', 'Username'])
